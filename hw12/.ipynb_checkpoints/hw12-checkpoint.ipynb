# %%
import warnings
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv('AEP_hourly.csv', index_col=0)
data.head()
# Out:
#                       AEP_MW
# Datetime
# 2004-12-31 01:00:00  13478.0
# 2004-12-31 02:00:00  12865.0
# 2004-12-31 03:00:00  12577.0
# 2004-12-31 04:00:00  12517.0
# 2004-12-31 05:00:00  12670.0

# %%
data.index = pd.to_datetime(data.index)
data = data['AEP_MW'].resample('W').mean()
data.dropna(inplace=True)
data.shape
# Out:
# (723,)

# %%
data.plot(figsize=(15, 6))
plt.show()

# %%
p = d = q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(data,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:15991.815850663686
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:15282.17211681799
# ARIMA(0, 0, 0)x(0, 0, 2, 12)12 - AIC:14173.840783925232
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:13237.715490593238
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:12515.385591910046
# ARIMA(0, 0, 0)x(0, 1, 2, 12)12 - AIC:12060.008237536582
# ARIMA(0, 0, 0)x(0, 2, 0, 12)12 - AIC:13914.590030932539
# ARIMA(0, 0, 0)x(0, 2, 1, 12)12 - AIC:13145.773416566644
# ARIMA(0, 0, 0)x(0, 2, 2, 12)12 - AIC:12846.645075601145
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:13254.87188215095
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:12988.606173991002
# ARIMA(0, 0, 0)x(1, 0, 2, 12)12 - AIC:12553.49737607026
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:12307.801795666408
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:12250.442738115084
# ARIMA(0, 0, 0)x(1, 1, 2, 12)12 - AIC:12002.794593186336
# ARIMA(0, 0, 0)x(1, 2, 0, 12)12 - AIC:12626.455572883508
# ARIMA(0, 0, 0)x(1, 2, 1, 12)12 - AIC:12377.301080913596
# ARIMA(0, 0, 0)x(1, 2, 2, 12)12 - AIC:12126.707419758457
# ARIMA(0, 0, 0)x(2, 0, 0, 12)12 - AIC:12308.069532331894
# ARIMA(0, 0, 0)x(2, 0, 1, 12)12 - AIC:12279.5862028709
# ARIMA(0, 0, 0)x(2, 0, 2, 12)12 - AIC:12252.101103014997
# ARIMA(0, 0, 0)x(2, 1, 0, 12)12 - AIC:12080.889267969855
# ARIMA(0, 0, 0)x(2, 1, 1, 12)12 - AIC:11969.85976246238
# ARIMA(0, 0, 0)x(2, 1, 2, 12)12 - AIC:11939.59451586864
# ARIMA(0, 0, 0)x(2, 2, 0, 12)12 - AIC:12303.163931498924
# ARIMA(0, 0, 0)x(2, 2, 1, 12)12 - AIC:12152.430122163658
# ARIMA(0, 0, 0)x(2, 2, 2, 12)12 - AIC:12077.90367053933
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:15446.929382520611
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:14154.73940788443
# ARIMA(0, 0, 1)x(0, 0, 2, 12)12 - AIC:13515.334964801934
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:12795.685102166291
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:12132.667893242466
# ARIMA(0, 0, 1)x(0, 1, 2, 12)12 - AIC:11757.42044377471
# ARIMA(0, 0, 1)x(0, 2, 0, 12)12 - AIC:13500.923763187939
# ARIMA(0, 0, 1)x(0, 2, 1, 12)12 - AIC:12438.39801121066
# ARIMA(0, 0, 1)x(0, 2, 2, 12)12 - AIC:11905.660810243746
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:12826.470605578541
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:15007.765323785958
# ARIMA(0, 0, 1)x(1, 0, 2, 12)12 - AIC:12152.455065149145
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:12094.137786726842
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:11998.251956777289
# ARIMA(0, 0, 1)x(1, 1, 2, 12)12 - AIC:11735.391943607063
# ARIMA(0, 0, 1)x(1, 2, 0, 12)12 - AIC:12423.727735782368
# ARIMA(0, 0, 1)x(1, 2, 1, 12)12 - AIC:12071.970974607102
# ARIMA(0, 0, 1)x(1, 2, 2, 12)12 - AIC:11810.443281094322
# ARIMA(0, 0, 1)x(2, 0, 0, 12)12 - AIC:12094.37145643467
# ARIMA(0, 0, 1)x(2, 0, 1, 12)12 - AIC:12045.460022338222
# ARIMA(0, 0, 1)x(2, 1, 0, 12)12 - AIC:11864.376956307107
# ARIMA(0, 0, 1)x(2, 1, 1, 12)12 - AIC:11754.86858187087

# %%
mod = sm.tsa.statespace.SARIMAX(data,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9599      0.022    -43.781      0.000      -1.003      -0.917
# ma.L1          0.9804      0.017     57.077      0.000       0.947       1.014
# ar.S.L12      -0.1010      0.044     -2.274      0.023      -0.188      -0.014
# ma.S.L12      -0.9422      0.020    -47.062      0.000      -0.981      -0.903
# sigma2      1.245e+06   6.41e+04     19.425      0.000    1.12e+06    1.37e+06
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-10-01'), dynamic=False)
pred_ci = pred.conf_int()

# %%
ax = data['2004':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7)

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('Mw')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = data['2017-10-01':]

mse = ((y_forecasted - y_truth) ** 2).mean()
print('MSE offorecasts is {}'.format(round(mse, 2)))
# Out:
# MSE offorecasts is 1616388.37
